# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %%
# Data Science Tools and Ecosystems

# %% [markdown]
# # Data Science Tools and Ecosystems

# %% [markdown]
# ## In this notebook, Data Science Tools and Ecosytems are summarized.

# %% [markdown]
# __Objectives:__
# - List popular languages used by Data Scientists
# - List libraries that are commonly used by Data Scientists
# - Demonstrate basic arithmetic evaluation in python

# %% [markdown]
# # Some of the popular languages data scientists use are:
#   1. Python
#   2. R
#   3. Julia

# %% [markdown]
# # Some of the commonly used libraries used by Data Scientists include:
# 1. pandas
# 2. NumPy
# 3. scikit-learn

# %% [markdown]
# | Data Science Tools |
# | -------------------- |
# | R studio |
# | Jupyter Notebooks |
# | Google Colaboratory |

# %% [markdown]
# ### Below are some examples of evaluating arithmetic expressions in python:

# %%
sales = 1545+2142
tax = .07 * sales
print ("Sales is equal to" , sales)
print ("Tax is equal to" , round(tax, 2))
# Out:
# Sales is equal to 3687
# Tax is equal to 258.09

# %%
s = 7.5
var = s**2
print ("Variance is equal to" , var)
# Out:
# Variance is equal to 56.25

# %%
#This is a simple arithmetic expression to multiply then add integers
x = (3*4)+5
print(x)
# Out:
# 17

# %%
#This will convert 200 minutes to hours by dividing by 60
num_minutes = 200
hours = num_minutes/60
print ("The number of hours is" , hours)
# Out:
# The number of hours is 3.3333333333333335

# %% [markdown]
# ## Author:
# Jehiah Burchfield
